# %%
import pandas as pd
import numpy as np
import os
from tqdm import tqdm
from uszipcode import SearchEngine

# %%
data_dir = os.getcwd() + '/yelp_dataset'
print('Loading business data ...')
df_business = pd.read_json(os.path.join(data_dir, 'business.json'), lines=True)
# Out:
# Loading business data ...

# %%
len(df_business)
# Out:
# 192609

# %%
def enrich_business_features(df):
    """
    enrich business in the US with population, population density,
    land area and median household income by searching with zipcode
    """
    # list of US state abbreviations
    states = ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DC", "DE", "FL", "GA", 
              "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", 
              "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", 
              "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC", 
              "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY"]
    # keep only businesses in the US
    df_business_us = df[df['state'].isin(states)]
    # get rid of missing zipcode items
    df_with_zipcode = df_business_us[~(df_business_us['postal_code']=='')] 
    # activate search engine which would provide more features relate to zipcode
    search = SearchEngine(simple_zipcode=True)
    df_zipcode = pd.DataFrame()
    zipcode = df_with_zipcode['postal_code'].unique()
    df_zipcode['postal_code'] = zipcode
    # perform searching and enrich features
    df_zipcode['population'] = [search.by_zipcode(i).to_dict()['population'] for i in tqdm(zipcode)]
    df_zipcode['population_density'] = [search.by_zipcode(i).to_dict()['population_density'] for i in tqdm(zipcode)]
    df_zipcode['land_area_in_sqmi'] = [search.by_zipcode(i).to_dict()['land_area_in_sqmi'] for i in tqdm(zipcode)]
    df_zipcode['median_household_income'] = [search.by_zipcode(i).to_dict()['median_household_income'] for i in tqdm(zipcode)]
    # merge features to business dataframe
    df = df_business_us.merge(df_zipcode, how='left', on='postal_code').dropna()
    
    return df

df_business = enrich_business_features(df_business)
# Out:
# 100%|██████████| 891/891 [00:00<00:00, 916.89it/s]
# 100%|██████████| 891/891 [00:00<00:00, 1365.59it/s]
# 100%|██████████| 891/891 [00:00<00:00, 1355.74it/s]
# 100%|██████████| 891/891 [00:00<00:00, 1341.04it/s]

# %%
df_business
# Out:
#                                                   address  \
# 1                               10110 Johnston Rd, Ste 15
# 3                          4209 Stuart Andrew Blvd, Ste F
# 4                    4545 E Tropicana Rd Ste 8, Tropicana
# 5                                   5940 W Union Hills Dr
# 6                                         21689 Lorain Rd
# 7                                 2450 E Indian School Rd
# 8                                119 Landings Dr, Ste 101
# 9                                         5981 Andrews Rd
# 10                                           4145 Erie St
# 11                              4848 E Cactus Rd, Ste 100
# 13
# 14                                450 Fremont St, Ste 179
# 15                                    3650 N 5th, Ste 100
# 16                                    6007 Dean Martin Dr
# 18                          7981 W Tropical Pkwy, Ste 120
# 19                                  6055 E Lake Mead Blvd
# 20                          3325 W Desert Inn Rd, Ste 101
# 21                                 8800 W Charleston Blvd
# 23                                    9020 B Albemarle Rd
# 25                                     6401 Morrison Blvd
# 26                                       15224 N 59th Ave
# 27                                        1318 S Vineyard
# 29                              560 E Germann Rd, Ste 107
# 31                                6775 Edmond St, Ste 210
# 33                                        4190 N Pecos Rd
# 34                                  14202 N Scottsdale Rd
# 36                                           709 W Ray Rd
# 37      2220 W Southern Ave, Ste 102, Endodontic Speci...
# 38                              13129 S Tryon St, Ste 120
# 40                         17025 N Scottsdale Rd, Ste 110
# ...                                                   ...
# 141908                                    855 Freeport Rd
# 141911                        2230 Corporate Cir, Ste 250
# 141913                                    30584 Lorain Rd
# 141915                          2033 E Warner Rd, Ste 115
# 141916                             1235 East Blvd, Ste 70
# 141917                     4920 W Thunderbird Rd, Ste 127
# 141920                            5611 S Valley View Blvd
# 141921                                      503 W Main St
# 141922                           3415 W Frye Rd, Ste 3415
# 141923                                  3005 Babcock Blvd
# 141924                                 4620 E Baseline Rd
# 141926                      1755 W University Dr, Ste 121
# 141927                           9719 Sam Furr Rd, Unit C
# 141928                                 7380 S Eastern Ave
# 141929                     5375 S Fort Apache Rd, Ste 101
# 141932                                2600 Lake Sahara Dr
# 141935
# 141937
# 141938                                   1927 E Carson St
# 141939                                     3863 Medina Rd
# 141940                  9526 Birkdale Crossing Dr, Ste 22
# 141943                       11165 S Eastern Ave, Ste 110
# 141944                      8164 S. Las Vegas Blvd., #100
# 141945                                   343 N Gilbert Rd
# 141947                                 5350 E Marriott Dr
# 141948                                    2179 S Green Rd
# 141950
# 141951                                    21230 N 22nd St
# 141952                                     4406 E Main St
# 141953                              3735 S Las Vegas Blvd
#
#                                                attributes  \
# 1       {'GoodForKids': 'True', 'NoiseLevel': 'u'avera...
# 3       {'BusinessAcceptsBitcoin': 'False', 'ByAppoint...
# 4       {'RestaurantsPriceRange2': '3', 'GoodForKids':...
# 5       {'RestaurantsPriceRange2': '2', 'ByAppointment...
# 6       {'ByAppointmentOnly': 'False', 'BusinessAccept...
# 7       {'RestaurantsTakeOut': 'True', 'BusinessParkin...
# 8       {'BusinessParking': '{'garage': False, 'street...
# 9       {'RestaurantsPriceRange2': '2', 'BusinessAccep...
# 10      {'RestaurantsTakeOut': 'True', 'BusinessParkin...
# 11      {'BusinessAcceptsCreditCards': 'True', 'Busine...
# 13                 {'BusinessAcceptsCreditCards': 'True'}
# 14                                {'GoodForKids': 'True'}
# 15                 {'BusinessAcceptsCreditCards': 'True'}
# 16      {'BikeParking': 'False', 'Ambience': '{'romant...
# 18      {'BusinessAcceptsCreditCards': 'True', 'Busine...
# 19      {'BikeParking': 'True', 'BusinessParking': '{'...
# 20                 {'BusinessAcceptsCreditCards': 'True'}
# 21      {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 23      {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 25      {'Alcohol': 'u'full_bar'', 'BusinessAcceptsCre...
# 26      {'ByAppointmentOnly': 'False', 'RestaurantsPri...
# 27      {'BusinessAcceptsCreditCards': 'True', 'ByAppo...
# 29                 {'BusinessAcceptsCreditCards': 'True'}
# 31      {'BusinessAcceptsCreditCards': 'False', 'ByApp...
# 33      {'RestaurantsPriceRange2': '1', 'BusinessAccep...
# 34      {'ByAppointmentOnly': 'False', 'BusinessAccept...
# 36      {'BusinessAcceptsCreditCards': 'True', 'BikePa...
# 37                          {'ByAppointmentOnly': 'True'}
# 38      {'RestaurantsPriceRange2': '2', 'BikeParking':...
# 40      {'BikeParking': 'True', 'BusinessParking': '{'...
# ...                                                   ...
# 141908  {'BikeParking': 'False', 'Ambience': '{'romant...
# 141911  {'BusinessAcceptsBitcoin': 'False', 'ByAppoint...
# 141913  {'ByAppointmentOnly': 'False', 'BusinessAccept...
# 141915  {'AcceptsInsurance': 'True', 'ByAppointmentOnl...
# 141916  {'RestaurantsPriceRange2': '2', 'BusinessAccep...
# 141917  {'BikeParking': 'True', 'RestaurantsPriceRange...
# 141920  {'Caters': 'True', 'RestaurantsTableService': ...
# 141921  {'OutdoorSeating': 'False', 'RestaurantsAttire...
# 141922  {'ByAppointmentOnly': 'False', 'GoodForKids': ...
# 141923  {'GoodForKids': 'True', 'BusinessAcceptsCredit...
# 141924  {'BusinessAcceptsCreditCards': 'True', 'ByAppo...
# 141926  {'ByAppointmentOnly': 'True', 'BusinessAccepts...
# 141927  {'Ambience': '{'touristy': False, 'hipster': F...
# 141928  {'BusinessAcceptsCreditCards': 'True', 'BikePa...
# 141929  {'ByAppointmentOnly': 'True', 'BusinessAccepts...
# 141932             {'BusinessAcceptsCreditCards': 'True'}
# 141935  {'ByAppointmentOnly': 'True', 'BusinessAccepts...
# 141937  {'BusinessAcceptsCreditCards': 'True', 'Busine...
# 141938  {'BusinessAcceptsCreditCards': 'True', 'ByAppo...
# 141939  {'RestaurantsPriceRange2': '2', 'HasTV': 'Fals...
# 141940  {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 141943  {'BusinessAcceptsCreditCards': 'True', 'GoodFo...
# 141944  {'OutdoorSeating': 'True', 'WiFi': 'u'free'', ...
# 141945  {'BusinessAcceptsCreditCards': 'True', 'ByAppo...
# 141947  {'BusinessAcceptsBitcoin': 'False', 'GoodForKi...
# 141948  {'RestaurantsPriceRange2': '2', 'BusinessParki...
# 141950             {'BusinessAcceptsCreditCards': 'True'}
# 141951  {'BusinessAcceptsCreditCards': 'True', 'ByAppo...
# 141952  {'RestaurantsPriceRange2': '1', 'BusinessAccep...
#
# 141929  Medical Spas, Hair Removal, Health & Medical, ...           Las Vegas
# 141932  Local Services, Education, Elementary Schools,...           Las Vegas
# 141935                         Home Services, Landscaping               Tempe
# 141937  Landscape Architects, Home Services, Gardeners...           Las Vegas
# 141938                    Chiropractors, Health & Medical          Pittsburgh
# 141939    Burgers, Restaurants, Fast Food, American (New)            Fairlawn
# 141940                         Nail Salons, Beauty & Spas        Huntersville
# 141943  Chinese Martial Arts, Specialty Schools, Educa...           Henderson
# 141944                                 Food, Coffee & Tea           Las Vegas
# 141945  Plumbing, Water Heater Installation/Repair, Pr...             Gilbert
# 141947  Golf, Hotels, Day Spas, Hotels & Travel, Event...             Phoenix
# 141948                         Food, Beer, Wine & Spirits  University Heights
# 141950  Water Purification Services, Water Heater Inst...     North Las Vegas
# 141951  Home Services, Contractors, Landscaping, Mason...             Phoenix
# 141952                             Beauty & Spas, Barbers                Mesa
# 141953                             Massage, Beauty & Spas           Las Vegas
#
#                                                     hours  is_open   latitude  \
# 1       {'Monday': '17:30-21:30', 'Wednesday': '17:30-...        1  35.092564
# 3       {'Monday': '7:0-23:0', 'Tuesday': '7:0-23:0', ...        1  35.190012
# 4       {'Monday': '10:0-19:0', 'Tuesday': '10:0-19:0'...        1  36.099872
# 5       {'Tuesday': '12:0-18:0', 'Wednesday': '10:0-18...        0  33.654815
# 6       {'Tuesday': '9:0-21:0', 'Wednesday': '9:0-21:0...        1  41.440825
# 7       {'Monday': '7:0-0:0', 'Tuesday': '7:0-0:0', 'W...        1  33.495194
# 8       {'Monday': '10:0-1:0', 'Tuesday': '10:0-1:0', ...        1  35.527410
# 9       {'Monday': '10:0-0:0', 'Tuesday': '10:0-0:0', ...        1  41.708520
# 10      {'Tuesday': '11:0-17:0', 'Wednesday': '11:0-17...        1  41.639860
# 11      {'Monday': '0:0-0:0', 'Tuesday': '9:0-19:0', '...        1  33.600071
# 13      {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...        1  36.116549
# 14      {'Monday': '11:0-0:0', 'Tuesday': '11:0-0:0', ...        1  36.169993
# 15      {'Monday': '9:0-18:0', 'Tuesday': '9:0-18:0', ...        1  36.225851
# 16      {'Thursday': '19:30-2:0', 'Friday': '19:30-3:0...        1  36.080168
# 18      {'Monday': '10:0-20:0', 'Tuesday': '10:0-20:0'...        1  36.271546
# 19      {'Monday': '11:0-21:0', 'Tuesday': '10:0-21:0'...        1  36.195615
# 20      {'Monday': '0:0-0:0', 'Tuesday': '8:0-18:0', '...        1  36.129424
# 21      {'Monday': '9:0-23:0', 'Tuesday': '9:0-23:0', ...        1  36.161805
# 23      {'Monday': '11:30-20:30', 'Tuesday': '11:30-20...        0  35.210510
# 25      {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...        0  35.156338
# 26      {'Tuesday': '9:0-17:0', 'Wednesday': '9:0-17:0...        0  33.623871
# 27      {'Monday': '9:0-18:0', 'Tuesday': '9:0-18:0', ...        1  33.391003
# 29      {'Monday': '0:0-0:0', 'Tuesday': '7:0-18:0', '...        1  33.278251
# 31      {'Monday': '8:0-17:0', 'Tuesday': '8:0-17:0', ...        1  36.066417
# 33      {'Monday': '0:0-0:0', 'Tuesday': '8:0-17:0', '...        1  36.236053
# 34      {'Tuesday': '10:0-18:0', 'Wednesday': '10:0-18...        0  33.616838
# 36      {'Monday': '12:0-21:0', 'Tuesday': '12:0-21:0'...        0  33.320386
# 37      {'Monday': '7:0-19:30', 'Tuesday': '7:0-19:30'...        1  33.393546
# 38      {'Monday': '10:0-20:0', 'Tuesday': '10:0-20:0'...        1  35.100725
# 40      {'Monday': '9:0-18:0', 'Tuesday': '9:0-18:0', ...        1  33.640308
# ...                                                   ...      ...        ...
# 141908  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...        1  40.486924
# 141911  {'Monday': '9:0-18:0', 'Tuesday': '9:0-18:0', ...        1  36.028157
# 141913  {'Monday': '10:0-23:0', 'Tuesday': '10:0-23:0'...        1  41.398855
# 141915  {'Monday': '8:0-18:0', 'Tuesday': '8:0-18:0', ...        1  33.334254
# 141916  {'Monday': '10:0-20:0', 'Tuesday': '10:0-20:0'...        1  35.203121
# 141917  {'Monday': '10:0-21:0', 'Tuesday': '10:0-21:0'...        1  33.611175
# 141920  {'Monday': '0:0-0:0', 'Tuesday': '11:30-20:30'...        1  36.087895
# 141921  {'Tuesday': '7:0-14:0', 'Wednesday': '7:0-14:0...        0  43.182853
# 141922  {'Monday': '9:0-21:0', 'Tuesday': '9:0-21:0', ...        1  33.306802
# 141923  {'Monday': '11:0-23:0', 'Tuesday': '11:0-23:0'...        1  40.514292
# 141924  {'Monday': '7:0-19:0', 'Tuesday': '7:0-19:0', ...        1  33.380379
# 141926  {'Monday': '9:0-17:0', 'Tuesday': '9:0-17:0', ...        1  33.421387
# 141927  {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...        1  35.443723
# 141928  {'Monday': '8:0-21:0', 'Tuesday': '8:0-21:0', ...        1  36.055748
# 141929  {'Monday': '10:0-18:0', 'Tuesday': '10:0-18:0'...        1  36.091170
# 141932  {'Monday': '6:30-18:30', 'Tuesday': '6:30-18:3...        1  36.141804
# 141935  {'Monday': '5:0-19:0', 'Tuesday': '5:0-19:0', ...        1  33.389758
# 141937  {'Monday': '0:0-0:0', 'Tuesday': '7:0-14:0', '...        1  36.168824
# 141938  {'Monday': '9:0-18:0', 'Tuesday': '9:0-18:0', ...        1  40.428768
# 141939  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...        1  41.136561
# 141940  {'Monday': '9:30-19:0', 'Tuesday': '9:30-19:0'...        1  35.443506
# 141943  {'Monday': '16:0-21:0', 'Tuesday': '16:0-21:0'...        1  35.989577
# 141944  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...        1  36.041407
# 141945  {'Monday': '7:0-17:0', 'Tuesday': '7:0-17:30',...        1  33.356540
# 141947  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...        1  33.683910
# 141948  {'Monday': '11:30-21:0', 'Tuesday': '9:0-21:0'...        0  41.500621
# 141950  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...        1  36.213732
# 141951  {'Monday': '7:0-15:0', 'Tuesday': '7:0-15:0', ...        1  33.679992
# 141952  {'Tuesday': '8:30-17:30', 'Wednesday': '8:30-1...        1  33.416137
# 141953  {'Monday': '10:0-0:0', 'Tuesday': '10:0-0:0', ...        0  36.107267
#
#          longitude                                           name postal_code  \
# 1       -80.859132                    Musashi Japanese Restaurant       28210
# 3       -80.887223                            Queen City Plumbing       28217
# 4      -115.074574                                      Supercuts       89121
# 5      -112.188568                        Vita Bella Fine Day Spa       85308
# 6       -81.854097                            Options Salon & Spa       44126
# 7      -112.028588                                      Taco Bell       85016
# 8       -80.868003                    The Kilted Buffalo Langtree       28117
# 9       -81.359556                                  Marco's Pizza       44060
# 10      -81.406396                                     Baby Cakes       44094
# 11     -111.977371                                     Knot Salon       85254
# 13     -115.088115                       Myron Hensel Photography       89121
# 14     -115.140685                                 Fremont Arcade       89101
# 15     -115.132800                            Las Vegas Motorcars       89032
# 16     -115.182756                                   Hunk Mansion       89118
# 18     -115.264484                                       Maurices       89149
# 19     -115.040529            Maria's Mexican Restaurant & Bakery       89156
# 20     -115.184443                                   AW Collision       89102
# 21     -115.287278                            Ross Dress for Less       89117
# 23      -80.690262                          So Cool Frozen Yogurt       28227
# 25      -80.831878                              Manzetti's Tavern       28211
# 26     -112.186448                         The Lounge Barber Shop       85306
# 27     -111.843620                                 Sonoma Village       85210
# 29     -111.777460                                         OzBraz       85297
# 31     -115.212541                 Wesley Friedman - FBC Mortgage       89118
# 33     -115.096454                                   Three Square       89115
# 34     -111.927310                         Key To Healing Massage       85254
# 36     -111.804652                       Bruster's Real Ice Cream       85233
# 37     -111.878890                      Stephen L Walker, DDS, MS       85202
# 38      -80.992079                   Mattress Firm Final Markdown       28278
# 40     -111.924528                            Nothing Bundt Cakes       85255
# ...            ...                                            ...         ...
# 141908  -79.891602                                        Chili's       15238
# 141911 -115.088426          Brenkus Team - Keller Williams Realty       89074
# 141913  -81.958136                                 Tattoo Faction       44070
# 141915 -111.900502                             Gentle Care Dental       85284
# 141916  -80.845783                         IDOLIZE Brows & Beauty       28203
# 141917 -112.164863                              Vaporice Glendale       85306
# 141920 -115.190329                               Jessie Rae's BBQ       89118
# 141921  -89.220335                      Gotham Provisions Company       53590
# 141922 -111.885570                                    Great Clips       85226
# 141923  -80.007399                          Kniess'miniature Golf       15237
# 141924 -111.734730                 Arizona Spine & Joint Hospital       85206
# 141926 -111.968139                              Priv-Energy Group       85281
# 141927  -80.864550                      Antico Italian Restaurant       28078
# 141928 -115.117081                           99 Cents Only Stores       89123
# 141929 -115.298280                             Ageless Aesthetics       89148
# 141932 -115.282388                           The Lakes KinderCare       89117
# 141935 -111.934364                      Adrian Torres Landscaping       85282
# 141937 -115.218557                  Premier Landscape Maintenance       89107
# 141938  -79.977941                    Ploucha Chiropractic Center       15203
# 141939  -81.639712                                      Five Guys       44333
# 141940  -80.886257                                     In 2 Nails       28078
# 141943 -115.101495                      Las Vegas Kung Fu Academy       89052
# 141944 -115.171698                                      Starbucks       89123
# 141945 -111.789367                        Phend Plumbing & Rooter       85234
# 141947 -111.966235  JW Marriott Phoenix Desert Ridge Resort & Spa       85054
# 141948  -81.518241                      Cedar Green Wine & Cheese       44121
# 141950 -115.177059                             Sanderson Plumbing       89032
# 141951 -112.035569                                 Phoenix Pavers       85024
# 141952 -111.735743                          Beasley's Barber Shop       85205
# 141953 -115.171920                                 Oriental Relax       89109
#
#         review_count  stars state  population  population_density  \
# 1                170    4.0    NC     42263.0              3327.0
# 3                  4    4.0    NC     24204.0              1634.0
# 4                  3    3.5    NV     64096.0              6969.0
# 5                  8    5.0    AZ     63876.0              3682.0
# 6                  8    4.5    OH     16771.0              3615.0
# 7                 18    3.0    AZ     33896.0              3752.0
# 8                  9    3.5    NC     35454.0               888.0
# 9                 16    4.0    OH     60211.0              1563.0
# 10                 7    3.0    OH     35234.0               899.0
# 11                 5    5.0    AZ     45801.0              3360.0
# 13                21    5.0    NV     64096.0              6969.0
# 14                38    4.5    NV     46055.0              8604.0
# 15                 3    3.5    NV     40297.0              3930.0
# 16               107    4.0    NV     19318.0              1825.0
# 18                 4    5.0    NV     31143.0              2595.0
# 19               184    4.5    NV     27794.0               857.0
# 20                52    4.5    NV     35759.0              6675.0
# 21                38    3.5    NV     55416.0              6076.0
# 23                 6    4.5    NC     49635.0              1283.0
# 25                16    3.5    NC     28523.0              2647.0
# 26                 6    3.5    AZ     24191.0              4318.0
# 27                 6    2.5    AZ     36464.0              5539.0
# 29                12    5.0    AZ     26979.0              2557.0
# 31                 6    5.0    NV     19318.0              1825.0
# 33                44    5.0    NV     58794.0              2351.0
# 34                10    5.0    AZ     45801.0              3360.0
# 36                57    4.5    AZ     37564.0              3859.0
# 37                 3    5.0    AZ     37275.0              5942.0
# 38                 4    5.0    NC     19283.0               677.0
# 40               174    4.0    AZ     37270.0               426.0
# ...              ...    ...   ...         ...                 ...
# 141908            39    2.5    PA     13162.0               804.0
# 141911            37    4.0    NV     47095.0              5247.0
# 141913            13    4.5    OH     32902.0              2820.0
# 141915            40    4.5    AZ     16479.0              2124.0
# 141916            98    4.5    NC     11315.0              3411.0
# 141917            21    3.5    AZ     24191.0              4318.0
# 141920           595    4.5    NV     19318.0              1825.0
# 141921            18    4.0    WI     36294.0               544.0
# 141922            10    3.0    AZ     37376.0               466.0
# 141923            18    4.5    PA     41895.0              1730.0
# 141924             6    4.5    AZ     33154.0              3470.0
# 141926             8    2.0    AZ     57348.0              4296.0
# 141927           142    4.5    NC     52133.0               817.0
# 141928            15    3.0    NV     56300.0              5283.0
# 141929            12    4.5    NV     39712.0              3224.0
# 141932             7    4.0    NV     55416.0              6076.0
# 141935            20    4.0    AZ     48671.0              4355.0
# 141937             3    1.0    NV     36282.0              6646.0
# 141938             5    5.0    PA      9949.0              6739.0
# 141939            22    4.0    OH     18763.0               674.0
# 141940            32    3.5    NC     52133.0               817.0
# 141943            15    4.5    NV     47214.0               909.0
# 141944           138    3.0    NV     56300.0              5283.0
# 141945            47    5.0    AZ     50014.0              4201.0
# 141947           441    4.0    AZ      5384.0               598.0
# 141948            12    3.0    OH     33220.0              5296.0
# 141950             9    5.0    NV     40297.0              3930.0
# 141951            14    4.5    AZ     22898.0               813.0
# 141952            15    4.5    AZ     39858.0              4073.0
# 141953             3    4.0    NV      7770.0              1753.0
#
#         land_area_in_sqmi  median_household_income
# 1                   12.70                  54915.0
# 3                   14.81                  38832.0
# 4                    9.20                  40836.0
# 5                   17.35                  68796.0
# 6                    4.64                  52988.0
# 7                    9.03                  46233.0
# 8                   39.91                  78026.0
# 9                   38.52                  64446.0
# 10                  39.21                  56278.0
# 11                  13.63                  90718.0
# 13                   9.20                  40836.0
# 14                   5.35                  22401.0
# 15                  10.25                  51734.0
# 16                  10.58                  51250.0
# 18                  12.00                  69273.0
# 19                  32.45                  44420.0
# 20                   5.36                  32562.0
# 21                   9.12                  54556.0
# 23                  38.70                  51527.0
# 25                  10.78                  70403.0
# 26                   5.60                  56321.0
# 27                   6.58                  36586.0
# 29                  10.55                  84097.0
# 31                  10.58                  51250.0
# 33                  25.01                  33496.0
# 34                  13.63                  90718.0
# 36                   9.74                  75365.0
# 37                   6.27                  42649.0
# 38                  28.48                  76566.0
# 40                  87.57                 111042.0
# ...                   ...                      ...
# 141908              16.38                  79194.0
# 141911               8.98                  68383.0
# 141913              11.67                  59288.0
# 141915               7.76                 117052.0
# 141916               3.32                  64604.0
# 141917               5.60                  56321.0
# 141920              10.58                  51250.0
# 141921              66.76                  70122.0
# 141922              80.16                  74005.0
# 141923              24.21                  69103.0
# 141924               9.56                  45680.0
# 141926              13.35                  30582.0
# 141927              63.80                  83519.0
# 141928              10.66                  59629.0
# 141929              12.32                  64084.0
# 141932               9.12                  54556.0
# 141935              11.18                  50455.0
# 141937               5.46                  44271.0
# 141938               1.48                  43734.0
# 141939              27.84                  77530.0
# 141940              63.80                  83519.0
# 141943              51.92                  75555.0
# 141944              10.66                  59629.0
# 141945              11.90                  76632.0
# 141947               9.00                  67488.0
# 141948               6.27                  53095.0
# 141950              10.25                  51734.0
# 141951              28.18                  64776.0
# 141952               9.79                  44469.0
# 141953               4.43                  40074.0
#
# [96632 rows x 18 columns]

# %%
# https://pypi.org/project/uszipcode/
# Out:
# <function Pattern.findall(string, pos=0, endpos=9223372036854775807)>

# %%
96632/192606
# Out:
# 0.5017081503172279
